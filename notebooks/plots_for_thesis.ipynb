# %% [markdown]
# # This notebook will be used to draw the needed plots for my thesis

# %% [markdown]
# ### Breast cancer distribution pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# #### For the training data

# %%
labels = 'Luminal A', 'Luminal B', 'Basal', 'Her2-enriched', 'Normal-like'
#sizes = [415, 176, 136, 65, 25]
sizes = [546, 208, 179, 81, 39]

plt.rcParams.update({'font.size': 22})

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(p=pct,v=val)
    return my_autopct

fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(111)

# fig1, ax1 = plt.subplots()
ax.pie(sizes, labels=labels,
        shadow=False, autopct=make_autopct(sizes), startangle=90, colors=['seagreen', 'firebrick', 'royalblue', 'darkorange', 'mediumpurple'])
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.savefig('../figures/brca_all_pie.pdf', bbox_inches='tight')

# %% [markdown]
# #### For the test data

# %%
labels = 'Luminal A', 'Luminal B', 'Basal', 'Her2-enriched', 'Normal-like'
sizes = [131, 32, 43, 16, 14]

plt.rcParams.update({'font.size': 22})

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{v:d}'.format(p=pct,v=val)
    return my_autopct

fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(111)

# fig1, ax1 = plt.subplots()
ax.pie(sizes, labels=labels,
        shadow=False, autopct=make_autopct(sizes), startangle=90, colors=['seagreen', 'firebrick', 'royalblue', 'darkorange', 'mediumpurple'])
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


plt.savefig('../figures/brca_test_pie.pdf', bbox_inches='tight')

# %% [markdown]
# # Plot with all values explored to regularise the Logistic Regression algorithm

# %%
cs = [0.001,0.01,0.1,1,10,100,1000,10000]
results = [0.166, 0.509, 0.797, 0.875, 0.884, 0.871, 0.857, 0.841]
lambda_res = {"lambda":[0.001,0.01,0.1,1,10,100,1000,10000], "accuracy":[0.166, 0.509, 0.797, 0.875, 0.884, 0.871, 0.857, 0.841]}
lambda_res_df = pd.DataFrame.from_dict(lambda_res)

# %%
fig = plt.figure(figsize = (10,5))
plt.style.use('default')
ax = fig.add_subplot(111)
xs = np.arange(8)
plt.plot(results, color="seagreen", marker="o")#, height=results, color="seagreen", width=0.5)
ax.set_ylabel('Accuracy', fontsize=18)
ax.set_xlabel('λ values', fontsize=18)
plt.xticks(xs, cs)
fig.tight_layout()
plt.savefig('../figures/lambda_tuning_line.pdf', bbox_inches='tight')
